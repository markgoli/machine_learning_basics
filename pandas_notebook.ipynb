# %%
# !pip install pandas

# %%
import pandas as pd 
print(pd.__version__)
# Out:
# 2.1.3

# %% [markdown]
# # what can we do with this package?
# - series and data frames
# - Conditional filtering and useful methods
# - Missing data
# - Group by operations
# - Combining data frames
# - Text methods and Time methods
# - Input and Outputs

# %%
# SERIES 
# This is a data structure in pandas that holds an array of information along with a named index.
# the named index differitiates this from a simple numpy array
# Formal defn. One-Dimension nd array with axis labels

# %%
import numpy as np
import pandas as pd

# %%
# help(pd.Series)

# %%
myindex = ['USA', 'Canada', 'Mexico', 'Uganda']

mydata = [1023, 4523, 5600, 5737]

# %%
my_series = pd.Series(data=mydata, index=myindex)

# %%
my_series
# Out:
# USA       1023
# Canada    4523
# Mexico    5600
# Uganda    5737
# dtype: int64

# %%
my_series['Uganda']
# Out:
# 5737

# %%
# using dictionaries 
age = {'Sam': 4, 'Mary': 6, "John": 7, 'Dad': 30}

# %%
agser = pd.Series(age)
agser
# Out:
# Sam      4
# Mary     6
# John     7
# Dad     30
# dtype: int64

# %%
agser["Dad"]
# Out:
# 30

# %%
len(agser)
# Out:
# 4

# %%
agser
# Out:
# Sam      4
# Mary     6
# John     7
# Dad     30
# dtype: int64

# %%
agser.keys()
# Out:
# Index(['Sam', 'Mary', 'John', 'Dad'], dtype='object')

# %%
#broadcasting operation.

np.array([1,2]) * 2
# Out:
# array([2, 4])

# %%
agser / 100
# Out:
# Sam     0.04
# Mary    0.06
# John    0.07
# Dad     0.30
# dtype: float64

# %% [markdown]
# # Data frames
# - this is a table of columns and rows in pandas that we can easily restructure and filter
# - Formal Defn: A group of pandas series objects that share the same index.

# %%
# creating a dataframe 
np.random.seed(101)
mydata = np.random.randint(0,101, (4,3))
mydata
# Out:
# array([[95, 11, 81],
#        [70, 63, 87],
#        [75,  9, 77],
#        [40,  4, 63]])

# %%
myindex = ['CA', 'NY', 'UG', 'TZ']

# %%
my_columns = ['Jan', 'Feb', 'Mar']

# %%
dataframe = pd.DataFrame(mydata, myindex, my_columns)
dataframe
# Out:
#     Jan  Feb  Mar
# CA   95   11   81
# NY   70   63   87
# UG   75    9   77
# TZ   40    4   63

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, CA to TZ
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Jan     4 non-null      int32
#  1   Feb     4 non-null      int32
#  2   Mar     4 non-null      int32
# dtypes: int32(3)
# memory usage: 80.0+ bytes

# %% [markdown]
# # Reading CSV Files

# %%
pwd
# Out:
# 'C:\\Users\\HP\\Desktop\\CS\\Projects\\Machine_learning\\ML_Basics'

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is C848-016E
#
#  Directory of C:\Users\HP\Desktop\CS\Projects\Machine_learning\ML_Basics
#
# 01/27/2024  09:47 PM    <DIR>          .
# 01/27/2024  09:47 PM    <DIR>          ..
# 01/27/2024  01:02 PM    <DIR>          .ipynb_checkpoints
# 01/27/2024  03:34 PM            16,532 Natural Language Processing.ipynb
# 01/27/2024  08:36 PM            28,969 numpy_notebook.ipynb
# 01/27/2024  09:47 PM            12,621 pandas_notebook.ipynb
#                3 File(s)         58,122 bytes
#                3 Dir(s)  315,823,063,040 bytes free

# %%
# importing and reading csv files 

df = pd.read_csv('C:\\Users\\HP\\Desktop\\CS\\Projects\\Datasets\\diabetes.csv')

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=768, step=1)

# %%
df.head(20)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148             72             35        0  33.6
# 1             1       85             66             29        0  26.6
# 2             8      183             64              0        0  23.3
# 3             1       89             66             23       94  28.1
# 4             0      137             40             35      168  43.1
# 5             5      116             74              0        0  25.6
# 6             3       78             50             32       88  31.0
# 7            10      115              0              0        0  35.3
# 8             2      197             70             45      543  30.5
# 9             8      125             96              0        0   0.0
# 10            4      110             92              0        0  37.6
# 11           10      168             74              0        0  38.0
# ...

# %%
df.tail(8)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 760            2       88             58             26       16  28.4
# 761            9      170             74             31        0  44.0
# 762            9       89             62              0        0  22.5
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 760                     0.766   22        0
# 761                     0.403   43        1
# 762                     0.142   33        0
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.describe().transpose()
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               768.0    3.845052    3.369578   0.000   1.00000
# Glucose                   768.0  120.894531   31.972618   0.000  99.00000
# BloodPressure             768.0   69.105469   19.355807   0.000  62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000   0.00000
# Insulin                   768.0   79.799479  115.244002   0.000   0.00000
# BMI                       768.0   31.992578    7.884160   0.000  27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
# Outcome                   768.0    0.348958    0.476951   0.000   0.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# ...

# %%
df.transpose()
# Out:
#                               0       1        2       3        4        5    \
# Pregnancies                 6.000   1.000    8.000   1.000    0.000    5.000
# Glucose                   148.000  85.000  183.000  89.000  137.000  116.000
# BloodPressure              72.000  66.000   64.000  66.000   40.000   74.000
# SkinThickness              35.000  29.000    0.000  23.000   35.000    0.000
# Insulin                     0.000   0.000    0.000  94.000  168.000    0.000
# BMI                        33.600  26.600   23.300  28.100   43.100   25.600
# DiabetesPedigreeFunction    0.627   0.351    0.672   0.167    2.288    0.201
# Age                        50.000  31.000   32.000  21.000   33.000   30.000
# Outcome                     1.000   0.000    1.000   0.000    1.000    0.000
#
#                              6        7        8        9    ...      758  \
# Pregnancies                3.000   10.000    2.000    8.000  ...    1.000
# ...

# %% [markdown]
# ### Retrieving information from a dataframe

# %%
## Colunms 

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
# lets say we're only interested in doing operations on Pregnancies column.
type(df['Pregnancies'])
# Out:
# pandas.core.series.Series

# %%
# grabing a list of columns 

df[['BMI', 'Glucose', 'Insulin']]
# Out:
#       BMI  Glucose  Insulin
# 0    33.6      148        0
# 1    26.6       85        0
# 2    23.3      183        0
# 3    28.1       89       94
# 4    43.1      137      168
# ..    ...      ...      ...
# 763  32.9      101      180
# 764  36.8      122        0
# 765  26.2      121      112
# 766  30.1      126        0
# 767  30.4       93        0
#
# [768 rows x 3 columns]

# %%
# creating new columns eg DiabetesPedigreeFunction_In_%age
# df.head(20)
100 * df['DiabetesPedigreeFunction']
# Out:
# 0       62.7
# 1       35.1
# 2       67.2
# 3       16.7
# 4      228.8
#        ...
# 763     17.1
# 764     34.0
# 765     24.5
# 766     34.9
# 767     31.5
# Name: DiabetesPedigreeFunction, Length: 768, dtype: float64

# %%
df['DiabetesPedigreeFunction_In_%age'] = 100 * df['DiabetesPedigreeFunction']

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome  DiabetesPedigreeFunction_In_%age
# 0                     0.627   50        1                              62.7
# 1                     0.351   31        0                              35.1
# 2                     0.672   32        1                              67.2
# 3                     0.167   21        0                              16.7
# 4                     2.288   33        1                             228.8

# %%
type(df['DiabetesPedigreeFunction_In_%age'])
# Out:
# pandas.core.series.Series

# %%
# Removing columns df.drop()

df.drop('DiabetesPedigreeFunction_In_%age', axis=1)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  DiabetesPedigreeFunction_In_%age
# ...

# %%
# permanent droping 

df = df.drop('DiabetesPedigreeFunction_In_%age', axis=1)

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.shape
# Out:
# (768, 9)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=768, step=1)

# %%
# grabbing rows using integer locations ---- df.iloc

### ----- using labelled locations  ----> df.loc

df.iloc[767]
# Out:
# Pregnancies                  1.000
# Glucose                     93.000
# BloodPressure               70.000
# SkinThickness               31.000
# Insulin                      0.000
# BMI                         30.400
# DiabetesPedigreeFunction     0.315
# Age                         23.000
# Outcome                      0.000
# Name: 767, dtype: float64

# %%
df.iloc[2:8]
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
#
#    DiabetesPedigreeFunction  Age  Outcome
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# 5                     0.201   30        0
# 6                     0.248   26        1
# 7                     0.134   29        0

# %%
selected_rows = df.iloc[0:50]
selected_rows
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148             72             35        0  33.6
# 1             1       85             66             29        0  26.6
# 2             8      183             64              0        0  23.3
# 3             1       89             66             23       94  28.1
# 4             0      137             40             35      168  43.1
# 5             5      116             74              0        0  25.6
# 6             3       78             50             32       88  31.0
# 7            10      115              0              0        0  35.3
# 8             2      197             70             45      543  30.5
# 9             8      125             96              0        0   0.0
# 10            4      110             92              0        0  37.6
# 11           10      168             74              0        0  38.0
# ...

# %%
type(selceted_rows)
# Out:
# pandas.core.frame.DataFrame

# %%
selected_rows.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count    50.000000   50.000000      50.000000      50.000000   50.000000
# mean      5.420000  127.380000      69.180000      19.060000   81.540000
# std       3.505622   32.597039      22.603675      16.714176  153.142619
# min       0.000000   71.000000       0.000000       0.000000    0.000000
# 25%       2.250000  103.000000      64.500000       0.000000    0.000000
# 50%       5.500000  118.500000      72.000000      23.000000    0.000000
# 75%       8.000000  146.750000      81.500000      33.000000  113.750000
# max      13.000000  197.000000     110.000000      47.000000  846.000000
#
#              BMI  DiabetesPedigreeFunction        Age    Outcome
# count  50.000000                 50.000000  50.000000  50.000000
# mean   31.258000                  0.520820  37.280000   0.500000
# std     9.117601                  0.428392  11.514038   0.505076
# ...

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# # Conditional Filtering

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df[df['Glucose'] > 100]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 5              5      116             74              0        0  25.6
# 7             10      115              0              0        0  35.3
# ..           ...      ...            ...            ...      ...   ...
# 761            9      170             74             31        0  44.0
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
# wine_data = pd.read_csv('C:\\Users\\HP\\Desktop\\CS\\Projects\\Datasets\\wine.data')
# wine_data

# %%
# wine_data.info()

# %%
# multiple conditions 
# & - and 
# | - or 


df[(df['Glucose'] > 150) & (df['BloodPressure'] < 50 )]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 300            0      167              0              0        0  32.3
# 332            1      180              0              0        0  43.3
# 604            4      183              0              0        0  28.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 300                     0.839   30        1
# 332                     0.282   41        1
# 604                     0.212   36        1
